# %% [markdown]
# ## **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# # **READING DATASET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv', delimiter=',',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# # **PROCESS THE DATA**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,   4, 633,  56],
#        [  0,   0,   0, ..., 912,   2,  10],
#        [  0,   0,   0, ...,   7, 672,  29],
#        ...,
#        [  0,   0,   0, ...,  62, 116, 454],
#        [  0,   0,   0, ...,  86, 153,   5],
#        [  0,   0,   0, ...,  28, 196,  34]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: 'that',
#  20: 'now',
#  21: '2',
#  22: 'are',
#  23: 'not',
#  24: 'but',
#  25: 'so',
#  26: 'or',
#  27: 'can',
#  28: 'do',
#  29: 'at',
#  30: "i'm",
#  31: 'get',
#  32: 'be',
#  33: 'if',
#  34: 'with',
#  35: 'ur',
#  36: 'will',
#  37: 'just',
#  38: 'no',
#  39: 'this',
#  40: 'we',
#  41: '4',
#  42: 'when',
#  43: 'up',
#  44: 'gt',
#  45: 'lt',
#  46: 'ok',
#  47: 'how',
#  48: 'from',
#  49: 'free',
#  50: 'all',
#  51: 'go',
#  52: 'out',
#  53: 'what',
#  54: 'know',
#  55: 'like',
#  56: 'then',
#  57: 'got',
#  58: 'was',
#  59: 'come',
#  60: 'good',
#  61: 'am',
#  62: 'its',
#  63: 'day',
#  64: 'time',
#  65: 'love',
#  66: 'only',
#  67: 'send',
#  68: 'want',
#  69: 'text',
#  70: 'there',
#  71: 'he',
#  72: 'one',
#  73: 'going',
#  74: 'as',
#  75: 'need',
#  76: "i'll",
#  77: 'txt',
#  78: 'by',
#  79: 'sorry',
#  80: 'lor',
#  81: 'r',
#  82: 'still',
#  83: 'da',
#  84: 'back',
#  85: 'our',
#  86: 'she',
#  87: 'about',
#  88: 'home',
#  89: 'stop',
#  90: 'see',
#  91: 'k',
#  92: 'today',
#  93: 'n',
#  94: 'reply',
#  95: 'dont',
#  96: "don't",
#  97: 'take',
#  98: 'her',
#  99: 'mobile',
#  100: 'pls',
#  101: 'hi',
#  102: 'think',
#  103: 'please',
#  104: 'any',
#  105: 'new',
#  106: 'tell',
#  107: 'here',
#  108: 'some',
#  109: 'later',
#  110: 'phone',
#  111: 'they',
#  112: 'dear',
#  113: 'ì',
#  114: 'well',
#  115: 'week',
#  116: 'been',
#  117: 'd',
#  118: 'has',
#  119: 'did',
#  120: 'too',
#  121: 'hope',
#  122: 'who',
#  123: 'much',
#  124: 'msg',
#  125: 'more',
#  126: '1',
#  127: 'great',
#  128: 'hey',
#  129: 'happy',
#  130: 'him',
#  131: 'an',
#  132: 'where',
#  133: 'night',
#  134: 'claim',
#  135: 'give',
#  136: 'oh',
#  137: 'make',
#  138: 'wat',
#  139: 'work',
#  140: 'should',
#  141: 'way',
#  142: 'www',
#  143: 'number',
#  144: 'had',
#  145: 'prize',
#  146: 'c',
#  147: 'doing',
#  148: 'message',
#  149: 'right',
#  150: 'after',
#  151: 'tomorrow',
#  152: 'yes',
#  153: 'said',
#  154: 'e',
#  155: "it's",
#  156: 'already',
#  157: 'say',
#  158: 'really',
#  159: 'why',
#  160: 'ask',
#  161: 'cash',
#  162: 'yeah',
#  163: 'life',
#  164: 'meet',
#  165: 'very',
#  166: 'find',
#  167: 'amp',
#  168: 'miss',
#  169: 'last',
#  170: '3',
#  171: 'thanks',
#  172: 'them',
#  173: 'babe',
#  174: 't',
#  175: 'im',
#  176: 'morning',
#  177: 'also',
#  178: 'nokia',
#  179: 'sure',
#  180: 'win',
#  181: 'would',
#  182: 'lol',
#  183: 'cos',
#  184: 'won',
#  185: 'b',
#  186: '150p',
#  187: 'let',
#  188: 'every',
#  189: 'keep',
#  190: 'us',
#  191: 'pick',
#  192: 'over',
#  193: 'care',
#  194: 'contact',
#  195: 'min',
#  196: 'anything',
#  197: 'sent',
#  198: 'something',
#  199: 's',
#  200: 'com',
#  201: 'buy',
#  202: 'cant',
#  203: 'urgent',
#  204: 'someone',
#  205: 'uk',
#  206: 'first',
#  207: 'thing',
#  208: "i've",
#  209: 'money',
#  210: 'feel',
#  211: 'soon',
#  212: '5',
#  213: 'were',
#  214: 'which',
#  215: 'off',
#  216: 'before',
#  217: 'around',
#  218: 'again',
#  219: 'customer',
#  220: 'service',
#  221: 'gonna',
#  222: "can't",
#  223: 'next',
#  224: 'many',
#  225: 'gud',
#  226: 'sleep',
#  227: 'even',
#  228: 'wait',
#  229: 'tonight',
#  230: 'leave',
#  231: 'place',
#  232: 'down',
#  233: 'always',
#  234: 'tone',
#  235: 'per',
#  236: 'his',
#  237: 'could',
#  238: 'went',
#  239: 'chat',
#  240: '50',
#  241: 'v',
#  242: 'nice',
#  243: 'ya',
#  244: 'things',
#  245: 'other',
#  246: 'ìï',
#  247: 'hello',
#  248: 'late',
#  249: 'wish',
#  250: 'sms',
#  251: 'wan',
#  252: 'friends',
#  253: "that's",
#  254: '16',
#  255: 'name',
#  256: 'done',
#  257: 'fine',
#  258: "you're",
#  259: 'dun',
#  260: 'haha',
#  261: 'year',
#  262: 'coming',
#  263: 'same',
#  264: 'co',
#  265: 'heart',
#  266: 'thought',
#  267: 'people',
#  268: 'help',
#  269: 'may',
#  270: 'special',
#  271: 'talk',
#  272: 'guaranteed',
#  273: 'holiday',
#  274: 'y',
#  275: 'told',
#  276: '6',
#  277: 'try',
#  278: 'waiting',
#  279: 'friend',
#  280: 'smile',
#  281: 'live',
#  282: 'use',
#  283: 'best',
#  284: "didn't",
#  285: 'getting',
#  286: 'yet',
#  287: 'thk',
#  288: 'thats',
#  289: 'having',
#  290: 'mins',
#  291: 'lunch',
#  292: 'stuff',
#  293: 'man',
#  294: '18',
#  295: '7',
#  296: 'finish',
#  297: 'check',
#  298: 'meeting',
#  299: 'ready',
#  300: 'person',
#  301: 'real',
#  302: 'better',
#  303: 'being',
#  304: 'house',
#  305: 'job',
#  306: 'play',
#  307: 'draw',
#  308: 'days',
#  309: 'god',
#  310: 'few',
#  311: 'mind',
#  312: 'yup',
#  313: 'cs',
#  314: 'car',
#  315: 'class',
#  316: 'never',
#  317: 'trying',
#  318: 'bit',
#  319: 'receive',
#  320: 'word',
#  321: 'line',
#  322: 'than',
#  323: 'yo',
#  324: 'å£1',
#  325: 'problem',
#  326: 'half',
#  327: 'dinner',
#  328: 'lot',
#  329: 'x',
#  330: 'end',
#  331: 'dat',
#  332: 'long',
#  333: 'might',
#  334: 'account',
#  335: 'birthday',
#  336: 'ill',
#  337: 'nothing',
#  338: 'because',
#  339: 'another',
#  340: 'camera',
#  341: 'into',
#  342: 'lar',
#  343: 'enjoy',
#  344: 'latest',
#  345: 'cool',
#  346: 'world',
#  347: 'sir',
#  348: 'shows',
#  349: 'guys',
#  350: 'offer',
#  351: 'two',
#  352: 'eat',
#  353: 'chance',
#  354: 'month',
#  355: 'remember',
#  356: 'å£1000',
#  357: 'wk',
#  358: 'aight',
#  359: 'plan',
#  360: 'early',
#  361: 'liao',
#  362: 'shopping',
#  363: 'awarded',
#  364: 'ever',
#  365: 'minutes',
#  366: '1st',
#  367: 'shall',
#  368: 'bad',
#  369: 'maybe',
#  370: 'wanna',
#  371: 'shit',
#  372: 'once',
#  373: 'weekend',
#  374: 'does',
#  375: 'between',
#  376: 'tv',
#  377: 'll',
#  378: 'girl',
#  379: 'start',
#  380: 'boy',
#  381: 'ah',
#  382: 'luv',
#  383: 'code',
#  384: 'sweet',
#  385: 'hear',
#  386: 'guess',
#  387: 'left',
#  388: 'watching',
#  389: 'everything',
#  390: "he's",
#  391: 'box',
#  392: 'orange',
#  393: 'speak',
#  394: 'award',
#  395: 'probably',
#  396: 'big',
#  397: 'hour',
#  398: 'den',
#  399: 'forgot',
#  400: 'while',
#  401: 'those',
#  402: 'dunno',
#  403: 'came',
#  404: 'rate',
#  405: 'po',
#  406: 'join',
#  407: 'quite',
#  408: 'must',
#  409: 'room',
#  410: 'pa',
#  411: 'bt',
#  412: 'baby',
#  413: 'cost',
#  414: '2nd',
#  415: "there's",
#  416: 'kiss',
#  417: 'pay',
#  418: 'thanx',
#  419: 'enough',
#  420: 'video',
#  421: 'called',
#  422: 'fun',
#  423: 'watch',
#  424: 'didnt',
#  425: 'xmas',
#  426: 'network',
#  427: 'landline',
#  428: 'says',
#  429: 'wif',
#  430: 'until',
#  431: 'actually',
#  432: 'collect',
#  433: 'anyway',
#  434: 'part',
#  435: 'ringtone',
#  436: 'm',
#  437: '9',
#  438: 'leh',
#  439: 'bed',
#  440: 'since',
#  441: '10',
#  442: 'wife',
#  443: 'dis',
#  444: 'sexy',
#  445: 'look',
#  446: 'selected',
#  447: 'office',
#  448: 'asked',
#  449: 'put',
#  450: 'working',
#  451: 'wont',
#  452: '150ppm',
#  453: 'xxx',
#  454: "how's",
#  455: '000',
#  456: 'apply',
#  457: 'abt',
#  458: 'times',
#  459: 'important',
#  460: 'means',
#  461: 'though',
#  462: 'wanted',
#  463: 'evening',
#  464: 'town',
#  465: 'thank',
#  466: 'school',
#  467: 'easy',
#  468: 'little',
#  469: '8',
#  470: 'calls',
#  471: 'sat',
#  472: 'okay',
#  473: 'collection',
#  474: 're',
#  475: 'texts',
#  476: 'gift',
#  477: 'mail',
#  478: 'missed',
#  479: 'jus',
#  480: 'update',
#  481: 'decimal',
#  482: 'face',
#  483: 'able',
#  484: 'goes',
#  485: 'pain',
#  486: 'tmr',
#  487: 'wen',
#  488: 'bus',
#  489: 'alright',
#  490: 'reach',
#  491: 'looking',
#  492: 'without',
#  493: 'wake',
#  494: 'hav',
#  495: 'away',
#  496: 'online',
#  497: 'price',
#  498: "haven't",
#  499: 'fuck',
#  500: 'princess',
#  501: 'oso',
#  502: 'feeling',
#  503: "''",
#  504: "what's",
#  505: 'true',
#  506: 'de',
#  507: 'music',
#  508: 'å£5000',
#  509: 'worry',
#  510: 'lei',
#  511: 'mob',
#  512: 'tones',
#  513: 'hair',
#  514: 'yours',
#  515: 'juz',
#  516: 'else',
#  517: 'colour',
#  518: 'missing',
#  519: 'details',
#  520: 'most',
#  521: 'family',
#  522: 'å£100',
#  523: 'yesterday',
#  524: '10p',
#  525: "won't",
#  526: 'entry',
#  527: 'weekly',
#  528: 'hurt',
#  529: 'driving',
#  530: 'wot',
#  531: 'dude',
#  532: 'double',
#  533: 'guy',
#  534: 'answer',
#  535: 'book',
#  536: 'net',
#  537: 'g',
#  538: 'bored',
#  539: 'show',
#  540: 'friendship',
#  541: 'dad',
#  542: '500',
#  543: 'messages',
#  544: 'haf',
#  545: 'plus',
#  546: 'bring',
#  547: 'points',
#  548: 'afternoon',
#  549: 'attempt',
#  550: 'sch',
#  551: 'test',
#  552: 'top',
#  553: 'busy',
#  554: 'goin',
#  555: 'change',
#  556: 'valid',
#  557: 'story',
#  558: 'ard',
#  559: 'hot',
#  560: 'game',
#  561: 'stay',
#  562: 'comes',
#  563: 'row',
#  564: 'leaving',
#  565: 'id',
#  566: '8007',
#  567: 'wid',
#  568: 'run',
#  569: 'food',
#  570: 'huh',
#  571: 'pounds',
#  572: 'tot',
#  573: 'pics',
#  574: 'tried',
#  575: "we'll",
#  576: 'minute',
#  577: 'plz',
#  578: 'chikku',
#  579: 'sae',
#  580: "we're",
#  581: 'these',
#  582: 'rite',
#  583: 'walk',
#  584: 'taking',
#  585: 'saying',
#  586: 'shop',
#  587: 'lets',
#  588: 'havent',
#  589: 'question',
#  590: 'bonus',
#  591: 'tomo',
#  592: 'national',
#  593: 'noe',
#  594: 'made',
#  595: 'words',
#  596: 'making',
#  597: 'makes',
#  598: '86688',
#  599: 'happen',
#  600: 'till',
#  601: 'address',
#  602: 'wil',
#  603: 'order',
#  604: 'calling',
#  605: 'pub',
#  606: 'delivery',
#  607: 'both',
#  608: 'todays',
#  609: 'together',
#  610: 'awesome',
#  611: 'vouchers',
#  612: 'nite',
#  613: 'club',
#  614: 'ring',
#  615: 'http',
#  616: 'yourself',
#  617: 'years',
#  618: 'wants',
#  619: 'hours',
#  620: 'til',
#  621: 'congrats',
#  622: 'search',
#  623: 'saw',
#  624: 'sad',
#  625: 'date',
#  626: 'auction',
#  627: 'gr8',
#  628: 'movie',
#  629: 'post',
#  630: 'lesson',
#  631: 'believe',
#  632: 'å£500',
#  633: 'trip',
#  634: 'available',
#  635: 'set',
#  636: 'mine',
#  637: 'drive',
#  638: 'private',
#  639: '11',
#  640: 'break',
#  641: 'far',
#  642: 'mean',
#  643: 'await',
#  644: 'email',
#  645: 'final',
#  646: 'beautiful',
#  647: 'forget',
#  648: 'everyone',
#  649: 'sister',
#  650: 'eve',
#  651: 'charge',
#  652: 'ha',
#  653: 'head',
#  654: 'poly',
#  655: 'simple',
#  656: 'visit',
#  657: 'thinking',
#  658: 'aft',
#  659: 'sleeping',
#  660: 'dreams',
#  661: 'lucky',
#  662: 'pic',
#  663: 'coz',
#  664: 'close',
#  665: 'carlos',
#  666: 'pobox',
#  667: 'smoke',
#  668: 'either',
#  669: 'smiling',
#  670: 'don',
#  671: 'games',
#  672: 'drop',
#  673: 'anytime',
#  674: 'services',
#  675: 'second',
#  676: 'took',
#  677: 'statement',
#  678: 'identifier',
#  679: 'expires',
#  680: 'tel',
#  681: "c's",
#  682: 'nt',
#  683: 'okie',
#  684: "you've",
#  685: 'decided',
#  686: 'bout',
#  687: 'drink',
#  688: 'å£2000',
#  689: 'light',
#  690: 'news',
#  691: 'sea',
#  692: 'w',
#  693: 'loving',
#  694: 'saturday',
#  695: 'hard',
#  696: 'lose',
#  697: "doesn't",
#  698: 'college',
#  699: 'suite342',
#  700: '2lands',
#  701: 'tho',
#  702: 'touch',
#  703: 'ltd',
#  704: 'xx',
#  705: 'sounds',
#  706: 'msgs',
#  707: 'choose',
#  708: 'rs',
#  709: 'winner',
#  710: 'worth',
#  711: 'full',
#  712: 'started',
#  713: 'dating',
#  714: 'takes',
#  715: 'frnd',
#  716: 'knw',
#  717: 'whatever',
#  718: 'lots',
#  719: 'telling',
#  720: 'card',
#  721: 'needs',
#  722: '\x89û',
#  723: '750',
#  724: 'pm',
#  725: 'used',
#  726: 'hit',
#  727: 'treat',
#  728: 'fast',
#  729: 'read',
#  730: 'opt',
#  731: 'found',
#  732: 'company',
#  733: 'pretty',
#  734: 'gone',
#  735: 'finished',
#  736: 'brother',
#  737: 'parents',
#  738: 'anyone',
#  739: 'cause',
#  740: 'mates',
#  741: 'kind',
#  742: 'secret',
#  743: 'happened',
#  744: '800',
#  745: 'un',
#  746: '100',
#  747: 'info',
#  748: 'quiz',
#  749: 'listen',
#  750: 'old',
#  751: 'player',
#  752: 'land',
#  753: 'alone',
#  754: 'credit',
#  755: 'hmmm',
#  756: 'camcorder',
#  757: '08000930705',
#  758: "you'll",
#  759: 'log',
#  760: 'thinks',
#  761: 'sun',
#  762: 'wonderful',
#  763: 'whats',
#  764: 'goodmorning',
#  765: 'ni8',
#  766: 'sis',
#  767: 'wit',
#  768: 'friday',
#  769: 'girls',
#  770: 'neva',
#  771: 'tc',
#  772: 'å£3',
#  773: 'etc',
#  774: 'happiness',
#  775: 'meant',
#  776: '30',
#  777: 'nope',
#  778: 'boytoy',
#  779: 'least',
#  780: "she's",
#  781: 'each',
#  782: 'their',
#  783: 'weeks',
#  784: 'wrong',
#  785: 'mobileupd8',
#  786: '08000839402',
#  787: 'angry',
#  788: 'cut',
#  789: 'outside',
#  790: 'hold',
#  791: 'unsubscribe',
#  792: 'oredi',
#  793: '2003',
#  794: 'redeemed',
#  795: 'couple',
#  796: 'hungry',
#  797: 'hows',
#  798: 'yar',
#  799: 'crazy',
#  800: 'gotta',
#  801: 'park',
#  802: 'area',
#  803: 'stupid',
#  804: 'bslvyl',
#  805: '12hrs',
#  806: 'numbers',
#  807: 'met',
#  808: 'surprise',
#  809: 'fr',
#  810: 'frnds',
#  811: 'reason',
#  812: '03',
#  813: 'darlin',
#  814: 'type',
#  815: 'talking',
#  816: 'å£350',
#  817: 'f',
#  818: 'content',
#  819: 'ten',
#  820: 'computer',
#  821: 'valued',
#  822: 'finally',
#  823: 'na',
#  824: 'information',
#  825: 'gas',
#  826: 'fucking',
#  827: 'seeing',
#  828: 'prob',
#  829: 'reading',
#  830: 'india',
#  831: 'project',
#  832: 'luck',
#  833: 'blue',
#  834: "'",
#  835: 'savamob',
#  836: 'offers',
#  837: 'smth',
#  838: 'earlier',
#  839: 'direct',
#  840: 'felt',
#  841: 'open',
#  842: 'hee',
#  843: 'ass',
#  844: 'dnt',
#  845: 'download',
#  846: 'hand',
#  847: 'st',
#  848: 'gal',
#  849: 'gn',
#  850: 'heard',
#  851: 'sunday',
#  852: '04',
#  853: 'askd',
#  854: 'seen',
#  855: 'store',
#  856: 'swing',
#  857: 'gd',
#  858: 'march',
#  859: 'fone',
#  860: 'bath',
#  861: 'side',
#  862: 'laptop',
#  863: 'case',
#  864: 'feels',
#  865: 'eg',
#  866: 'mrng',
#  867: 'pass',
#  868: 'phones',
#  869: 'extra',
#  870: 'th',
#  871: 'within',
#  872: 'semester',
#  873: 'song',
#  874: 'o',
#  875: 'uncle',
#  876: 'supposed',
#  877: 'å£2',
#  878: '0800',
#  879: 'course',
#  880: 'mobiles',
#  881: 'mum',
#  882: 'wow',
#  883: 'questions',
#  884: 'picking',
#  885: 'yr',
#  886: 'hg',
#  887: 'almost',
#  888: 'understand',
#  889: 'invited',
#  890: 'w1j6hl',
#  891: 'rock',
#  892: 'knew',
#  893: 'balance',
#  894: 'lovely',
#  895: 'chennai',
#  896: 'txting',
#  897: 'sending',
#  898: 'reward',
#  899: 'operator',
#  900: 'red',
#  901: 'lost',
#  902: 'voucher',
#  903: 'checking',
#  904: 'cum',
#  905: 'reveal',
#  906: 'welcome',
#  907: 'congratulations',
#  908: "wasn't",
#  909: 'confirm',
#  910: 'wana',
#  911: 'merry',
#  912: 'christmas',
#  913: 'plans',
#  914: 'truth',
#  915: 'charged',
#  916: 'mate',
#  917: '20',
#  918: 'ends',
#  919: 'enter',
#  920: 'somewhere',
#  921: 'wonder',
#  922: 'ex',
#  923: 'asking',
#  924: 'mayb',
#  925: 'die',
#  926: 'unlimited',
#  927: '87066',
#  928: 'rest',
#  929: 'whole',
#  930: 'point',
#  931: 'oops',
#  932: 'via',
#  933: 'loved',
#  934: 'mom',
#  935: 'party',
#  936: 'jay',
#  937: "isn't",
#  938: 'sort',
#  939: 'usf',
#  940: 'grins',
#  941: 'abiola',
#  942: 'blood',
#  943: 'support',
#  944: 'rental',
#  945: 'caller',
#  946: 'bcoz',
#  947: 'kate',
#  948: 'match',
#  949: 'discount',
#  950: 'press',
#  951: 'wishing',
#  952: 'mah',
#  953: 'mr',
#  954: 'own',
#  955: 'nyt',
#  956: 'asap',
#  957: 'fancy',
#  958: 'fantastic',
#  959: 'ldn',
#  960: 'txts',
#  961: 'eh',
#  962: 'crave',
#  963: 'rply',
#  964: 'gets',
#  965: 'currently',
#  966: 'rakhesh',
#  967: 'across',
#  968: 'std',
#  969: 'pray',
#  970: 'remove',
#  971: 'bank',
#  972: 'age',
#  973: 'myself',
#  974: 'motorola',
#  975: 'darren',
#  976: 'difficult',
#  977: '12',
#  978: 'lovable',
#  979: 'b4',
#  980: 'exam',
#  981: 'ge',
#  982: 'gym',
#  983: 'freemsg',
#  984: 'comin',
#  985: 'ipod',
#  986: 'knows',
#  987: 'frm',
#  988: 'dogging',
#  989: 'poor',
#  990: 'street',
#  991: 'snow',
#  992: 'sell',
#  993: 'hiya',
#  994: 'å£200',
#  995: 'wkly',
#  996: 'å£250',
#  997: 'whenever',
#  998: 'unless',
#  999: 'cheap',
#  1000: 'slow',
#  ...}

# %% [markdown]
# # **CREATING MODELS AND ADDING LAYERS**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# # **COMPILE THE MODEL**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           261792
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,033
# Trainable params: 317,033
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **FIT THE MODEL**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 21s 631ms/step - loss: 0.4471 - accuracy: 0.8630 - val_loss: 0.2688 - val_accuracy: 0.8586
# Epoch 2/10
# 30/30 [==============================] - 19s 639ms/step - loss: 0.1796 - accuracy: 0.9422 - val_loss: 0.1345 - val_accuracy: 0.9747

# %% [markdown]
# # **SAVE THE MODEL**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# # **TEST THE MODEL**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1248 - accuracy: 0.9773

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.125
#   Accuracy: 0.977
